# %% [markdown]
# ### Binary Classification with Keras

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### Read the train dataset

# %%
import pandas as pd
df = pd.read_csv('train_smoker.csv')
df.head()
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   55         165          60       81.0             0.5
# 1   1   70         165          65       89.0             0.6
# 2   2   20         170          75       81.0             0.4
# 3   3   35         180          95      105.0             1.5
# 4   4   30         165          60       80.5             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0              0.6              1               1       135  ...   40   75
# 1              0.7              2               2       146  ...   57  126
# 2              0.5              1               1       118  ...   45   93
# 3              1.2              1               1       131  ...   38  102
# 4              1.0              1               1       121  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# 0        16.5              1               1.0   22   25   27              0
# 1        16.2              1               1.1   27   23   37              1
# 2        17.4              1               0.8   27   31   53              0
# 3        15.9              1               1.0   20   27   30              1
# 4        15.4              1               0.8   19   13   17              0
#
#    smoking
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159256 entries, 0 to 159255
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   159256 non-null  int64
#  1   age                  159256 non-null  int64
#  2   height(cm)           159256 non-null  int64
#  3   weight(kg)           159256 non-null  int64
#  4   waist(cm)            159256 non-null  float64
#  5   eyesight(left)       159256 non-null  float64
#  6   eyesight(right)      159256 non-null  float64
#  7   hearing(left)        159256 non-null  int64
#  8   hearing(right)       159256 non-null  int64
#  9   systolic             159256 non-null  int64
#  10  relaxation           159256 non-null  int64
#  11  fasting blood sugar  159256 non-null  int64
#  12  Cholesterol          159256 non-null  int64
#  13  triglyceride         159256 non-null  int64
#  14  HDL                  159256 non-null  int64
#  15  LDL                  159256 non-null  int64
#  16  hemoglobin           159256 non-null  float64
#  17  Urine protein        159256 non-null  int64
#  18  serum creatinine     159256 non-null  float64
#  19  AST                  159256 non-null  int64
#  20  ALT                  159256 non-null  int64
#  21  Gtp                  159256 non-null  int64
#  22  dental caries        159256 non-null  int64
#  23  smoking              159256 non-null  int64
# dtypes: float64(5), int64(19)
# memory usage: 29.2 MB

# %% [markdown]
# ### Check missing values

# %%
df.isna().sum()
# Out:
# id                     0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# dental caries          0
# smoking                0
# dtype: int64

# %% [markdown]
# ### Seperate X and Y (Smoking)

# %%
X = df.drop(columns=['id', 'smoking'])
Y = df[['smoking']]

# %%
X.head()
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   55         165          60       81.0             0.5              0.6
# 1   70         165          65       89.0             0.6              0.7
# 2   20         170          75       81.0             0.4              0.5
# 3   35         180          95      105.0             1.5              1.2
# 4   30         165          60       80.5             1.5              1.0
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  triglyceride  \
# 0              1               1       135          87  ...           300
# 1              2               2       146          83  ...            55
# 2              1               1       118          75  ...           197
# 3              1               1       131          88  ...           203
# 4              1               1       121          76  ...            87
#
#    HDL  LDL  hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  \
# 0   40   75        16.5              1               1.0   22   25   27
# 1   57  126        16.2              1               1.1   27   23   37
# 2   45   93        17.4              1               0.8   27   31   53
# 3   38  102        15.9              1               1.0   20   27   30
# 4   44   93        15.4              1               0.8   19   13   17
#
#    dental caries
# 0              0
# 1              1
# 2              0
# 3              1
# 4              0
#
# [5 rows x 22 columns]

# %%
Y.head()
# Out:
#    smoking
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %%
Y.value_counts()
# Out:
# smoking
# 0          89603
# 1          69653
# Name: count, dtype: int64

# %% [markdown]
# ### Preprocessing X with pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
                           ('scaler', StandardScaler())])

# %%
X_pre = num_pipe.fit_transform(X)
X_pre
# Out:
# array([[ 0.90298511, -0.03026766, -0.56758078, ..., -0.08732581,
#         -0.29534174, -0.49686626],
#        [ 2.16963644, -0.03026766, -0.17031899, ..., -0.19998274,
#          0.0251244 ,  2.01261403],
#        [-2.05253466,  0.53669377,  0.62420461, ...,  0.25064496,
#          0.53787023, -0.49686626],
#        ...,
#        [-0.36366622, -0.59722908, -1.36210438, ..., -0.98858121,
#         -0.77604095, -0.49686626],
#        [ 0.480768  , -0.03026766,  0.62420461, ..., -0.53795351,
#          0.0251244 , -0.49686626],
#        [-0.36366622, -2.29811335, -1.75936618, ..., -0.59428197,
#         -0.61580788, -0.49686626]])

# %%
cols = num_pipe.get_feature_names_out()
cols
# Out:
# array(['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine',
#        'AST', 'ALT', 'Gtp', 'dental caries'], dtype=object)

# %%
X_pre = pd.DataFrame(X_pre, columns=cols)
X_pre.head()
# Out:
#         age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0  0.902985   -0.030268   -0.567581  -0.223489       -1.257856
# 1  2.169636   -0.030268   -0.170319   0.669577       -1.009169
# 2 -2.052535    0.536694    0.624205  -0.223489       -1.506543
# 3 -0.785883    1.670617    2.213252   2.455708        1.229017
# 4 -1.208100   -0.030268   -0.567581  -0.279305        1.229017
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  ...  \
# 0        -1.022156      -0.156725       -0.154865  0.981702    1.125777  ...
# 1        -0.767247       6.380587        6.457242  1.845852    0.681066  ...
# 2        -1.277064      -0.156725       -0.154865 -0.353802   -0.208355  ...
# 3         0.507296      -0.156725       -0.154865  0.667465    1.236955  ...
# 4        -0.002521      -0.156725       -0.154865 -0.118125   -0.097177  ...
#
#    triglyceride       HDL       LDL  hemoglobin  Urine protein  \
# 0      2.604429 -1.135246 -1.406581    1.189928      -0.213401
# 1     -1.097105  0.082162  0.404573    0.980315      -0.213401
# 2      1.048274 -0.777185 -0.767350    1.818767      -0.213401
# 3      1.138923 -1.278470 -0.447734    0.770702      -0.213401
# 4     -0.613639 -0.848797 -0.767350    0.421347      -0.213401
#
#    serum creatinine       AST       ALT       Gtp  dental caries
# 0          0.597927 -0.371570 -0.087326 -0.295342      -0.496866
# 1          1.155511  0.156700 -0.199983  0.025124       2.012614
# 2         -0.517239  0.156700  0.250645  0.537870      -0.496866
# 3          0.597927 -0.582878  0.025331 -0.199202       2.012614
# 4         -0.517239 -0.688532 -0.763267 -0.615808      -0.496866
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Apply train test split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.shape
# Out:
# (127404, 22)

# %%
xtest.shape
# Out:
# (31852, 22)

# %%
xtrain.shape[1]
# Out:
# 22

# %% [markdown]
# ### Create a Neural Network with Keras

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Dropout Layer acts as a Regularization. Randomly drop some percentage of neurons

# %%
model = Sequential()

# Hiden Layer 1
model.add(Dense(64, activation='relu', input_dim=xtrain.shape[1]))
# Dropout Layer 1
model.add(Dropout(0.2))

# Hiden Layer 2
model.add(Dense(32, activation='relu'))
# Dropout Layer 2
model.add(Dropout(0.2))

# Output Layer 
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1472
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 3585 (14.00 KB)
# Trainable params: 3585 (14.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'AUC'])

# %% [markdown]
# ### Fit the model

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=60)
# Out:
# Epoch 1/60
# 3186/3186 [==============================] - 12s 3ms/step - loss: 0.4827 - accuracy: 0.7566 - auc: 0.8360 - val_loss: 0.4598 - val_accuracy: 0.7734 - val_auc: 0.8568
# Epoch 2/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4672 - accuracy: 0.7683 - auc: 0.8487 - val_loss: 0.4537 - val_accuracy: 0.7753 - val_auc: 0.8583
# Epoch 3/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4630 - accuracy: 0.7707 - auc: 0.8516 - val_loss: 0.4518 - val_accuracy: 0.7752 - val_auc: 0.8598
# Epoch 4/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4616 - accuracy: 0.7710 - auc: 0.8528 - val_loss: 0.4502 - val_accuracy: 0.7765 - val_auc: 0.8605
# Epoch 5/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4597 - accuracy: 0.7717 - auc: 0.8540 - val_loss: 0.4502 - val_accuracy: 0.7768 - val_auc: 0.8611
# Epoch 6/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4591 - accuracy: 0.7733 - auc: 0.8548 - val_loss: 0.4497 - val_accuracy: 0.7759 - val_auc: 0.8607
# Epoch 7/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4575 - accuracy: 0.7737 - auc: 0.8557 - val_loss: 0.4498 - val_accuracy: 0.7760 - val_auc: 0.8611
# Epoch 8/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4577 - accuracy: 0.7739 - auc: 0.8555 - val_loss: 0.4500 - val_accuracy: 0.7758 - val_auc: 0.8607
# Epoch 9/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4576 - accuracy: 0.7735 - auc: 0.8558 - val_loss: 0.4488 - val_accuracy: 0.7769 - val_auc: 0.8611
# Epoch 10/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4566 - accuracy: 0.7745 - auc: 0.8562 - val_loss: 0.4488 - val_accuracy: 0.7754 - val_auc: 0.8611
# Epoch 11/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4558 - accuracy: 0.7752 - auc: 0.8571 - val_loss: 0.4490 - val_accuracy: 0.7765 - val_auc: 0.8611
# Epoch 12/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4561 - accuracy: 0.7745 - auc: 0.8567 - val_loss: 0.4486 - val_accuracy: 0.7759 - val_auc: 0.8615
# Epoch 13/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4554 - accuracy: 0.7751 - auc: 0.8574 - val_loss: 0.4492 - val_accuracy: 0.7760 - val_auc: 0.8610
# Epoch 14/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4554 - accuracy: 0.7764 - auc: 0.8574 - val_loss: 0.4485 - val_accuracy: 0.7771 - val_auc: 0.8616
# Epoch 15/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4551 - accuracy: 0.7757 - auc: 0.8575 - val_loss: 0.4474 - val_accuracy: 0.7771 - val_auc: 0.8622
# Epoch 16/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4546 - accuracy: 0.7757 - auc: 0.8580 - val_loss: 0.4474 - val_accuracy: 0.7774 - val_auc: 0.8617
# Epoch 17/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4546 - accuracy: 0.7752 - auc: 0.8578 - val_loss: 0.4470 - val_accuracy: 0.7780 - val_auc: 0.8627
# Epoch 18/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4538 - accuracy: 0.7754 - auc: 0.8584 - val_loss: 0.4467 - val_accuracy: 0.7774 - val_auc: 0.8623
# Epoch 19/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4542 - accuracy: 0.7766 - auc: 0.8583 - val_loss: 0.4476 - val_accuracy: 0.7775 - val_auc: 0.8617
# Epoch 20/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4540 - accuracy: 0.7764 - auc: 0.8583 - val_loss: 0.4478 - val_accuracy: 0.7763 - val_auc: 0.8619
# Epoch 21/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4541 - accuracy: 0.7759 - auc: 0.8584 - val_loss: 0.4478 - val_accuracy: 0.7778 - val_auc: 0.8623
# Epoch 22/60
# 3186/3186 [==============================] - 11s 3ms/step - loss: 0.4530 - accuracy: 0.7760 - auc: 0.8590 - val_loss: 0.4484 - val_accuracy: 0.7774 - val_auc: 0.8620
# Epoch 23/60
# 3186/3186 [==============================] - 11s 3ms/step - loss: 0.4529 - accuracy: 0.7766 - auc: 0.8591 - val_loss: 0.4476 - val_accuracy: 0.7772 - val_auc: 0.8619
# Epoch 24/60
# 3186/3186 [==============================] - 11s 4ms/step - loss: 0.4529 - accuracy: 0.7764 - auc: 0.8592 - val_loss: 0.4473 - val_accuracy: 0.7782 - val_auc: 0.8619
# Epoch 25/60
# 3186/3186 [==============================] - 11s 3ms/step - loss: 0.4525 - accuracy: 0.7772 - auc: 0.8591 - val_loss: 0.4475 - val_accuracy: 0.7771 - val_auc: 0.8618
# Epoch 26/60
# 3186/3186 [==============================] - 11s 3ms/step - loss: 0.4527 - accuracy: 0.7772 - auc: 0.8591 - val_loss: 0.4474 - val_accuracy: 0.7776 - val_auc: 0.8621
# Epoch 27/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4526 - accuracy: 0.7769 - auc: 0.8593 - val_loss: 0.4474 - val_accuracy: 0.7760 - val_auc: 0.8621
# Epoch 28/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4527 - accuracy: 0.7773 - auc: 0.8593 - val_loss: 0.4474 - val_accuracy: 0.7771 - val_auc: 0.8617
# Epoch 29/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4518 - accuracy: 0.7790 - auc: 0.8601 - val_loss: 0.4480 - val_accuracy: 0.7772 - val_auc: 0.8617
# Epoch 30/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4527 - accuracy: 0.7770 - auc: 0.8594 - val_loss: 0.4477 - val_accuracy: 0.7761 - val_auc: 0.8618
# Epoch 31/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4517 - accuracy: 0.7782 - auc: 0.8601 - val_loss: 0.4473 - val_accuracy: 0.7765 - val_auc: 0.8621
# Epoch 32/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4524 - accuracy: 0.7770 - auc: 0.8592 - val_loss: 0.4474 - val_accuracy: 0.7781 - val_auc: 0.8620
# Epoch 33/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4515 - accuracy: 0.7779 - auc: 0.8600 - val_loss: 0.4478 - val_accuracy: 0.7775 - val_auc: 0.8623
# Epoch 34/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4524 - accuracy: 0.7775 - auc: 0.8598 - val_loss: 0.4477 - val_accuracy: 0.7771 - val_auc: 0.8620
# Epoch 35/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4520 - accuracy: 0.7776 - auc: 0.8598 - val_loss: 0.4476 - val_accuracy: 0.7788 - val_auc: 0.8622
# Epoch 36/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4512 - accuracy: 0.7774 - auc: 0.8603 - val_loss: 0.4494 - val_accuracy: 0.7767 - val_auc: 0.8619
# Epoch 37/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4518 - accuracy: 0.7780 - auc: 0.8602 - val_loss: 0.4462 - val_accuracy: 0.7780 - val_auc: 0.8626
# Epoch 38/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4510 - accuracy: 0.7780 - auc: 0.8606 - val_loss: 0.4477 - val_accuracy: 0.7763 - val_auc: 0.8621
# Epoch 39/60
# 3186/3186 [==============================] - 11s 4ms/step - loss: 0.4520 - accuracy: 0.7780 - auc: 0.8599 - val_loss: 0.4475 - val_accuracy: 0.7771 - val_auc: 0.8621
# Epoch 40/60
# 3186/3186 [==============================] - 11s 4ms/step - loss: 0.4512 - accuracy: 0.7777 - auc: 0.8605 - val_loss: 0.4472 - val_accuracy: 0.7772 - val_auc: 0.8619
# Epoch 41/60
# 3186/3186 [==============================] - 12s 4ms/step - loss: 0.4519 - accuracy: 0.7773 - auc: 0.8599 - val_loss: 0.4494 - val_accuracy: 0.7779 - val_auc: 0.8621
# Epoch 42/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4513 - accuracy: 0.7774 - auc: 0.8603 - val_loss: 0.4504 - val_accuracy: 0.7774 - val_auc: 0.8625
# Epoch 43/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4509 - accuracy: 0.7786 - auc: 0.8607 - val_loss: 0.4475 - val_accuracy: 0.7774 - val_auc: 0.8626
# Epoch 44/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4510 - accuracy: 0.7784 - auc: 0.8604 - val_loss: 0.4474 - val_accuracy: 0.7760 - val_auc: 0.8620
# Epoch 45/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4517 - accuracy: 0.7774 - auc: 0.8601 - val_loss: 0.4474 - val_accuracy: 0.7760 - val_auc: 0.8618
# Epoch 46/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4508 - accuracy: 0.7787 - auc: 0.8610 - val_loss: 0.4476 - val_accuracy: 0.7776 - val_auc: 0.8619
# Epoch 47/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4507 - accuracy: 0.7780 - auc: 0.8605 - val_loss: 0.4480 - val_accuracy: 0.7769 - val_auc: 0.8616
# Epoch 48/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4509 - accuracy: 0.7788 - auc: 0.8608 - val_loss: 0.4483 - val_accuracy: 0.7766 - val_auc: 0.8617
# Epoch 49/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4506 - accuracy: 0.7789 - auc: 0.8607 - val_loss: 0.4473 - val_accuracy: 0.7772 - val_auc: 0.8624
# Epoch 50/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4507 - accuracy: 0.7787 - auc: 0.8607 - val_loss: 0.4477 - val_accuracy: 0.7779 - val_auc: 0.8621
# Epoch 51/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4505 - accuracy: 0.7786 - auc: 0.8609 - val_loss: 0.4470 - val_accuracy: 0.7763 - val_auc: 0.8624
# Epoch 52/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4508 - accuracy: 0.7787 - auc: 0.8606 - val_loss: 0.4515 - val_accuracy: 0.7769 - val_auc: 0.8622
# Epoch 53/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4509 - accuracy: 0.7787 - auc: 0.8607 - val_loss: 0.4482 - val_accuracy: 0.7791 - val_auc: 0.8622
# Epoch 54/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4507 - accuracy: 0.7787 - auc: 0.8607 - val_loss: 0.4469 - val_accuracy: 0.7790 - val_auc: 0.8622
# Epoch 55/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4499 - accuracy: 0.7783 - auc: 0.8612 - val_loss: 0.4476 - val_accuracy: 0.7784 - val_auc: 0.8621
# Epoch 56/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4503 - accuracy: 0.7785 - auc: 0.8609 - val_loss: 0.4470 - val_accuracy: 0.7790 - val_auc: 0.8623
# Epoch 57/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4501 - accuracy: 0.7786 - auc: 0.8610 - val_loss: 0.4468 - val_accuracy: 0.7781 - val_auc: 0.8622
# Epoch 58/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4499 - accuracy: 0.7793 - auc: 0.8614 - val_loss: 0.4481 - val_accuracy: 0.7788 - val_auc: 0.8621
# Epoch 59/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4500 - accuracy: 0.7787 - auc: 0.8609 - val_loss: 0.4469 - val_accuracy: 0.7784 - val_auc: 0.8627
# Epoch 60/60
# 3186/3186 [==============================] - 10s 3ms/step - loss: 0.4500 - accuracy: 0.7780 - auc: 0.8613 - val_loss: 0.4476 - val_accuracy: 0.7764 - val_auc: 0.8620

# %% [markdown]
# ### Plot the Learnings curve

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(hist.history['loss'], label='Train BCE')
plt.plot(hist.history['val_loss'], label='Test BCE')
plt.xlabel('epochs')
plt.ylabel('Binary Cross Entropy')
plt.title('Learning Curve')
plt.show()

# %% [markdown]
# ### Evaluate model on train and test

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 3982/3982 [==============================] - 8s 2ms/step - loss: 0.4417 - accuracy: 0.7825 - auc: 0.8670
# [0.44174623489379883, 0.7825186252593994, 0.8670490980148315]

# %%
model.evaluate(xtest, ytest)
# Out:
# 996/996 [==============================] - 2s 2ms/step - loss: 0.4560 - accuracy: 0.7716 - auc: 0.8562
# [0.45603999495506287, 0.7715684771537781, 0.8562130331993103]

# %% [markdown]
# ### Predecting train and test

# %%
yprob_tr = model.predict(xtrain)
yprob_ts = model.predict(xtest)
# Out:
# 3982/3982 [==============================] - 7s 2ms/step
# 996/996 [==============================] - 2s 2ms/step

# %%
yprob_tr[0:5]
# Out:
# array([[0.00746781],
#        [0.23709238],
#        [0.03888978],
#        [0.09843844],
#        [0.4796809 ]], dtype=float32)

# %% [markdown]
# ### Predicting the results
#
# threshold = 0.5
#
# if prob>=0.5 then smoker else non_smoker

# %%
ypred_tr = [1 if i>=0.5 else 0 for i in yprob_tr]
ypred_ts = [1 if i>=0.5 else 0 for i in yprob_ts]

# %%
ypred_tr[0:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
ypred_ts[0:5]
# Out:
# [1, 1, 1, 0, 1]

# %% [markdown]
# ### Create a confusion metrix for test results

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cf = confusion_matrix(ytest, ypred_ts)
cfd = ConfusionMatrixDisplay(cf)
cfd.plot()

# %% [markdown]
# ### Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, ypred_ts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78     17783
#            1       0.71      0.81      0.76     14069
#
#     accuracy                           0.77     31852
#    macro avg       0.77      0.78      0.77     31852
# weighted avg       0.78      0.77      0.77     31852

# %% [markdown]
# ### Save the model in .Keras format

# %%
model.save('SmokerClassification.keras')

# %% [markdown]
# ### Predicting results for test_smoker.csv File

# %%
xnew = pd.read_csv('test_smoker.csv')
xnew.head()
# Out:
#        id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0  159256   40         165          70       84.0             1.2
# 1  159257   80         160          60       93.0             1.0
# 2  159258   60         170          70       86.5             0.6
# 3  159259   40         160          50       67.0             0.3
# 4  159260   40         170          75       89.4             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# 0              1.2              1               1       130  ...
# 1              1.0              2               2       144  ...
# 2              0.7              1               1       117  ...
# 3              0.4              1               1       116  ...
# 4              0.9              1               1       132  ...
#
#    triglyceride  HDL  LDL  hemoglobin  Urine protein  serum creatinine  AST  \
# 0           186   49  115        14.2              1               0.9   19
# 1           158   35  104        13.0              1               1.1   20
# 2           173   39   88        15.4              1               1.4   38
# 3            47   75  128        14.5              1               0.6   25
# 4           100   39  123        16.5              1               1.0   30
#
#    ALT  Gtp  dental caries
# 0   25   32              0
# 1   12   24              0
# 2   60   36              0
# 3   18   10              1
# 4   39   27              1
#
# [5 rows x 23 columns]

# %%
xnew2 = xnew.drop(columns=['id'])
xnew2
# Out:
#         age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0        40         165          70       84.0             1.2
# 1        80         160          60       93.0             1.0
# 2        60         170          70       86.5             0.6
# 3        40         160          50       67.0             0.3
# 4        40         170          75       89.4             1.0
# ...     ...         ...         ...        ...             ...
# 106166   40         165          60       78.0             0.8
# 106167   40         170          85       95.0             1.2
# 106168   35         170          85       89.0             1.2
# 106169   40         160          60       67.0             0.7
# 106170   50         150          50       80.0             0.9
#
#         eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0                   1.2              1               1       130          89
# 1                   1.0              2               2       144          72
# 2                   0.7              1               1       117          75
# 3                   0.4              1               1       116          62
# 4                   0.9              1               1       132          94
# ...                 ...            ...             ...       ...         ...
# 106166              0.9              1               1       112          78
# 106167              1.2              1               1       130          90
# 106168              1.2              1               1       131          86
# 106169              0.8              1               1       120          80
# 106170              1.0              1               1       115          67
#
#         ...  triglyceride  HDL  LDL  hemoglobin  Urine protein  \
# 0       ...           186   49  115        14.2              1
# 1       ...           158   35  104        13.0              1
# 2       ...           173   39   88        15.4              1
# 3       ...            47   75  128        14.5              1
# 4       ...           100   39  123        16.5              1
# ...     ...           ...  ...  ...         ...            ...
# 106166  ...            82   59  149        16.4              1
# 106167  ...           186   44  100        16.0              2
# 106168  ...            76   53  142        15.9              1
# 106169  ...            81   55  103        13.9              1
# 106170  ...            96   48  144        13.0              1
#
#         serum creatinine  AST  ALT  Gtp  dental caries
# 0                    0.9   19   25   32              0
# 1                    1.1   20   12   24              0
# 2                    1.4   38   60   36              0
# 3                    0.6   25   18   10              1
# 4                    1.0   30   39   27              1
# ...                  ...  ...  ...  ...            ...
# 106166               1.1   24   31   28              0
# 106167               1.0   25   31   38              0
# 106168               0.8   33   32   24              1
# 106169               0.6   42   36   32              0
# 106170               0.6   18   11   17              1
#
# [106171 rows x 22 columns]

# %% [markdown]
# ### For new predictions always apply .transform

# %%
xnew2_pre = num_pipe.transform(xnew2)
xnew2_pre
# Out:
# array([[-0.36366622, -0.03026766,  0.22694281, ..., -0.08732581,
#         -0.13510867, -0.49686626],
#        [ 3.01407065, -0.59722908, -0.56758078, ..., -0.81959582,
#         -0.39148158, -0.49686626],
#        [ 1.32520222,  0.53669377,  0.22694281, ...,  1.88417036,
#         -0.00692221, -0.49686626],
#        ...,
#        [-0.78588333,  0.53669377,  1.4187282 , ...,  0.30697342,
#         -0.39148158,  2.01261403],
#        [-0.36366622, -0.59722908, -0.56758078, ...,  0.53228727,
#         -0.13510867, -0.49686626],
#        [ 0.480768  , -1.73115193, -1.36210438, ..., -0.87592428,
#         -0.61580788,  2.01261403]])

# %%
xnew2_pre = pd.DataFrame(xnew2_pre, columns=cols)
xnew2_pre.head()
# Out:
#         age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0 -0.363666   -0.030268    0.226943   0.111411        0.482955
# 1  3.014071   -0.597229   -0.567581   1.116110       -0.014419
# 2  1.325202    0.536694    0.226943   0.390494       -1.009169
# 3 -0.363666   -0.597229   -1.362104  -1.786353       -1.755231
# 4 -0.363666    0.536694    0.624205   0.714230       -0.014419
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  ...  \
# 0         0.507296      -0.156725       -0.154865  0.588906    1.348132  ...
# 1        -0.002521       6.380587        6.457242  1.688733   -0.541888  ...
# 2        -0.767247      -0.156725       -0.154865 -0.432361   -0.208355  ...
# 3        -1.531973      -0.156725       -0.154865 -0.510921   -1.653664  ...
# 4        -0.257430      -0.156725       -0.154865  0.746025    1.904021  ...
#
#    triglyceride       HDL       LDL  hemoglobin  Urine protein  \
# 0      0.882082 -0.490736  0.013932   -0.417106      -0.213401
# 1      0.459050 -1.493307 -0.376709   -1.255558      -0.213401
# 2      0.685674 -1.206858 -0.944914    0.421347      -0.213401
# 3     -1.217971  1.371182  0.475599   -0.207493      -0.213401
# 4     -0.417232 -1.206858  0.298035    1.189928      -0.213401
#
#    serum creatinine       AST       ALT       Gtp  dental caries
# 0          0.040344 -0.688532 -0.087326 -0.135109      -0.496866
# 1          1.155511 -0.582878 -0.819596 -0.391482      -0.496866
# 2          2.828261  1.318895  1.884170 -0.006922      -0.496866
# 3         -1.632406 -0.054608 -0.481625 -0.840134       2.012614
# 4          0.597927  0.473663  0.701273 -0.295342       2.012614
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Get the probabilities for prediction

# %%
prob = model.predict(xnew2_pre)
# Out:
# 3318/3318 [==============================] - 6s 2ms/step

# %%
prob
# Out:
# array([[0.5155341 ],
#        [0.22195992],
#        [0.36999223],
#        ...,
#        [0.43923685],
#        [0.15923357],
#        [0.02705608]], dtype=float32)

# %%
pred = [1 if i>=0.5 else 0 for i in prob]

# %%
pred[0:5]
# Out:
# [1, 0, 0, 0, 1]

# %% [markdown]
# ### Save the values in dataframe

# %%
df_final = xnew[['id']]
df_final
# Out:
#             id
# 0       159256
# 1       159257
# 2       159258
# 3       159259
# 4       159260
# ...        ...
# 106166  265422
# 106167  265423
# 106168  265424
# 106169  265425
# 106170  265426
#
# [106171 rows x 1 columns]

# %%
df_final['smoker_pred']=pred
df_final['smoker_prob']=prob

# %%
df_final
# Out:
#             id  smoker_pred  smoker_prob
# 0       159256            1     0.515534
# 1       159257            0     0.221960
# 2       159258            0     0.369992
# 3       159259            0     0.027875
# 4       159260            1     0.588152
# ...        ...          ...          ...
# 106166  265422            1     0.535362
# 106167  265423            1     0.726778
# 106168  265424            0     0.439237
# 106169  265425            0     0.159234
# 106170  265426            0     0.027056
#
# [106171 rows x 3 columns]

# %%
df_final['smoker_pred'].value_counts()
# Out:
# smoker_pred
# 0    53110
# 1    53061
# Name: count, dtype: int64

# %%
df_final['smoker_pred'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='smoker_pred'>

# %% [markdown]
# ### Save df_final to csv

# %%
df_final.to_csv('Resluts.csv', index='False')
